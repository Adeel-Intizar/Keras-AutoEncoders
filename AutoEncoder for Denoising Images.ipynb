# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.datasets import mnist
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# **Let's Plot the Noisy Images**

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = tf.keras.Input(shape=(28, 28, 1))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.Model(input_img, decoded, name='AutoEncoder')
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1699 - val_loss: 0.1166
# Epoch 2/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1126 - val_loss: 0.1080
# Epoch 3/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1074 - val_loss: 0.1049
# Epoch 4/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1047 - val_loss: 0.1031
# Epoch 5/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1027 - val_loss: 0.1010
# Epoch 6/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1012 - val_loss: 0.0997
# Epoch 7/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1001 - val_loss: 0.0986
# Epoch 8/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0992 - val_loss: 0.0979
# Epoch 9/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0985 - val_loss: 0.0974
# Epoch 10/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0981 - val_loss: 0.0973
# Epoch 11/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0975 - val_loss: 0.0964
# Epoch 12/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0971 - val_loss: 0.0962
# Epoch 13/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0969 - val_loss: 0.0960
# Epoch 14/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0966 - val_loss: 0.0961
# Epoch 15/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0964 - val_loss: 0.0956
# Epoch 16/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0961 - val_loss: 0.0955
# Epoch 17/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0960 - val_loss: 0.0953
# Epoch 18/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0958 - val_loss: 0.0952
# Epoch 19/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - val_loss: 0.0953
# Epoch 20/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0955 - val_loss: 0.0953
# Epoch 21/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0955 - val_loss: 0.0951
# Epoch 22/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0948
# Epoch 23/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0951
# Epoch 24/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0951 - val_loss: 0.0945
# Epoch 25/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 26/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0947
# Epoch 27/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0943
# Epoch 28/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - val_loss: 0.0944
# Epoch 29/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0942
# Epoch 30/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 31/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0942
# Epoch 32/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0943
# Epoch 33/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 34/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0940
# Epoch 35/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 36/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0941
# Epoch 37/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 38/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 39/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 40/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 41/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 42/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 43/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 44/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 45/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 46/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 47/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0937
# Epoch 48/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 49/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 50/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 51/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 52/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 53/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 54/100
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 55/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 56/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 57/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 58/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 59/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 60/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 61/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 62/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0934
# Epoch 63/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 64/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 65/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 66/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 67/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 68/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0938
# Epoch 69/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 70/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 71/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 72/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 73/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 74/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 75/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 76/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 77/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0937
# Epoch 78/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 79/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0936
# Epoch 80/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 81/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0933
# Epoch 82/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 83/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 84/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 85/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 86/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 87/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 88/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 89/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0932
# Epoch 90/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 91/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 92/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 93/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 94/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 95/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 96/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 98/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 99/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 100/100
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0932 - val_loss: 0.0932

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
